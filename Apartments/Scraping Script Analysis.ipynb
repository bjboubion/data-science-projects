# %% [markdown]
# # Web Scraping using BeautifulSoup4

# %%
import requests
from bs4 import BeautifulSoup
import pandas # I am using pandas to generate a csv file at the end of the script

# %% [markdown]
# ## What site should I scrape?
#
# ### Well, I will just use apartments.com for now and I will scrape (in this case) in the San Diego Area

# %%
base_url = "https://www.apartments.com/san-diego-ca/"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

# %% [markdown]
# ## Next, we use the requests library to hit the base_url
# ### We can take the content and set it to variable c

# %%
# To get the html contents
r = requests.get(base_url, headers=headers)
c = r.content

# %%
c
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n<html lang="en" data-placeholder-focus="false">\r\n<head>\r\n    <meta charset="utf-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\r\n    <meta name="format-detection" content="telephone=no" />\r\n    <meta name="format-detection" content="email=no" />\r\n    <meta name="HandheldFriendly" content="true" />\r\n    <title> Apartments for Rent in San Diego CA - Page 28 | Apartments.com</title>\r\n    <link rel="icon" href="/a/8a55f9/favicon.ico">\r\n        <link rel="canonical" href="https://www.apartments.com/san-diego-ca/28/" />\r\n        <meta name="keywords" content="San Diego apartments for rent, condos, townhomes, houses for rent" />\r\n    <link href="https://plus.google.com/+apartmentscom/" rel="publisher" />\r\n    <meta name="description" content="See all 6,516 apartments in San Diego, CA currently available for rent. Each Apartments.com listing has verified availability, rental rates, photos, floor plans and more." />\r\n    <meta name="language" content="en" />\r\n    <meta http-equiv="language" content="en">\r\n    <meta http-equiv="content-language" content="en-US">\r\n    <meta property="fb:app_id" content="739299276152207" />\r\n    <meta property="og:site_name" content="Apartments.com" />\r\n    <meta property="og:url" content="https://www.apartments.com/san-diego-ca/28/" />\r\n    <meta property="og:type" content="article" />\r\n    <meta property="og:title" content=" Apartments for Rent in San Diego CA - Page 28 | Apartments.com" />\r\n    <meta property="og:image" content="https://images1.apartments.com/i2/UDVgTCuIjwG9vgSKX5VCv0sXbCuqI4pFUYLWUaNzYuY/104/image.jpg" />\r\n    <meta property="og:updated_time" content="9/11/2018 8:15:43 PM" />\r\n    <meta property="og:description" content="We simplify the process of finding a new apartment by offering renters the most comprehensive database including millions of detailed and accurate apartment listings across the United States. Our innovative technology includes the POLYGON\xe2\x84\xa2 search tool that allows users to define their own search areas on a map and a Plan Commute feature that helps users search for rentals in proximity to their office." />\r\n    <meta name="twitter:card" content="summary_large_image">\r\n    <meta name="twitter:creator" content="&#64;apartmentscom">\r\n    <meta name="twitter:title" content=" Apartments for Rent in San Diego CA - Page 28 | Apartments.com">\r\n    <meta name="twitter:image" content="https://images1.apartments.com/i2/UDVgTCuIjwG9vgSKX5VCv0sXbCuqI4pFUYLWUaNzYuY/104/image.jpg">\r\n    <meta name="referrer" content="origin">\r\n            <link rel="alternate" hreflang="en-US" href="https://www.apartments.com/san-diego-ca/28/" />\r\n                <link rel="alternate" hreflang="x-default" href="https://www.apartments.com/san-diego-ca/28/" />\r\n            <link rel="alternate" hreflang="es-US" href="https://www.apartments.com/es/san-diego-ca/28/" />\r\n    \r\n        <link rel="prev" href="https://www.apartments.com/san-diego-ca/27/" />\r\n\r\n\r\n        <link rel="preload" href="/a/601697/content/fonts/apartmenticons.woff" as="font" crossorigin>\r\n        <link rel="preload" href="/a/48178f/content/fonts/lineto-costar-brown-regular.woff" as="font" crossorigin>\r\n        <link rel="preload" href="/a/0b286e/content/fonts/lineto-costar-brown-light.woff" as="font" crossorigin>\r\n        <link rel="preload" href="/a/d21ed8/content/fonts/lineto-costar-brown-bold.woff" as="font" crossorigin>\r\n    <link href="/content/style.bundle.css?v=0OGVLLMofIfQ35vIa8nNUE7obZR84iptQuvR93BQo1I" type="text/css" rel="stylesheet"/>\r\n    \r\n    <link href="/Modules/Search/Content/style.bundle.css?v=SIg9wW9ttGymNkbAKQaYD4xt0QO9l9RePgrwYf6pDx0" type="text/css" rel="stylesheet"/>\r\n\r\n    \r\n<script type="text/javascript">\r\n    if (window.location.hash) {\r\n        var hash = window.location.hash.substr(1);\r\n        if (ha ...

# %% [markdown]
# ## So while we have the actual content, it is HIDEOUS
# ### here is where Beautiful Soup comes into play

# %%
# To parse the html
soup = BeautifulSoup(c,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html data-placeholder-focus="false" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="email=no" name="format-detection"/>
# <meta content="true" name="HandheldFriendly"/>
# <title> Apartments for Rent in San Diego CA - Page 28 | Apartments.com</title>
# <link href="/a/8a55f9/favicon.ico" rel="icon"/>
# <link href="https://www.apartments.com/san-diego-ca/28/" rel="canonical">
# <meta content="San Diego apartments for rent, condos, townhomes, houses for rent" name="keywords"/>
# <link href="https://plus.google.com/+apartmentscom/" rel="publisher"/>
# <meta content="See all 6,516 apartments in San Diego, CA currently available for rent. Each Apartments.com listing has verified availability, rental rates, photos, floor plans and more." name="description"/>
# <meta content="en" name="language"/>
# <meta content="en" http-equiv="language"/>
# <meta content="en-US" http-equiv="content-language"/>
# <meta content="739299276152207" property="fb:app_id">
# <meta content="Apartments.com" property="og:site_name">
# <meta content="https://www.apartments.com/san-diego-ca/28/" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content=" Apartments for Rent in San Diego CA - Page 28 | Apartments.com" property="og:title"/>
# <meta content="https://images1.apartments.com/i2/UDVgTCuIjwG9vgSKX5VCv0sXbCuqI4pFUYLWUaNzYuY/104/image.jpg" property="og:image"/>
# <meta content="9/11/2018 8:15:43 PM" property="og:updated_time"/>
# <meta content="We simplify the process of finding a new apartment by offering renters the most comprehensive database including millions of detailed and accurate apartment listings across the United States. Our innovative technology includes the POLYGON™ search tool that allows users to define their own search areas on a map and a Plan Commute feature that helps users search for rentals in proximity to their office." property="og:description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@apartmentscom" name="twitter:creator"/>
# <meta content=" Apartments for Rent in San Diego CA - Page 28 | Apartments.com" name="twitter:title"/>
# <meta content="https://images1.apartments.com/i2/UDVgTCuIjwG9vgSKX5VCv0sXbCuqI4pFUYLWUaNzYuY/104/image.jpg" name="twitter:image"/>
# <meta content="origin" name="referrer"/>
# <link href="https://www.apartments.com/san-diego-ca/28/" hreflang="en-US" rel="alternate"/>
# <link href="https://www.apartments.com/san-diego-ca/28/" hreflang="x-default" rel="alternate"/>
# <link href="https://www.apartments.com/es/san-diego-ca/28/" hreflang="es-US" rel="alternate"/>
# <link href="https://www.apartments.com/san-diego-ca/27/" rel="prev"/>
# <link as="font" crossorigin="" href="/a/601697/content/fonts/apartmenticons.woff" rel="preload"/>
# <link as="font" crossorigin="" href="/a/48178f/content/fonts/lineto-costar-brown-regular.woff" rel="preload"/>
# <link as="font" crossorigin="" href="/a/0b286e/content/fonts/lineto-costar-brown-light.woff" rel="preload"/>
# <link as="font" crossorigin="" href="/a/d21ed8/content/fonts/lineto-costar-brown-bold.woff" rel="preload"/>
# <link href="/content/style.bundle.css?v=0OGVLLMofIfQ35vIa8nNUE7obZR84iptQuvR93BQo1I" rel="stylesheet" type="text/css">
# <link href="/Modules/Search/Content/style.bundle.css?v=SIg9wW9ttGymNkbAKQaYD4xt0QO9l9RePgrwYf6pDx0" rel="stylesheet" type="text/css">
# <script type="text/javascript">
#     if (window.location.hash) {
#         var hash = window.location.hash.substr(1);
#         if (hash && hash.indexOf('/') == 0) {
#             window.location.href = window.location.protocol + '//' + window.location.host + hash;
#         }
#     }
# </script>
# <script>bazadebezolkohpepadr="137316288"</script><script defer="" src="https://www.apartments.com/akam/10/82f471b" type="text/javascript"></script></link></link></meta></meta></link></head>
# <body class="desktop ">
# <div class="mainWrapper">
# <header class=" mainHeader" id="mainHeader">
# <nav class="mainHeaderNavigation" id="mainHeaderNavigation">
# <div class="menuSection">
# <button class="dropdownToggle primary homeBtn" id="headerMenuLink" type="button">
# <i class="hamburgerIcon"></i><span>Menu</span>
# </button>
# <div class="menuNavWrapper" id="menuNavWrapper">
# <div id="menuNavContainer">
# <div class="menuOpenWrapper">
# <span class="menuHeader" id="menuHeader"><i class="hamburgerIcon"></i><span class="menuText">Menu</span></span>
# <ul class="menuNavigation" id="menuNavigation">
# <li><a data-requirelogin="true" href="https://www.apartments.com/customers/" rel="nofollow">Customer Tools</a></li>
# <li><a data-requirelogin="true" href="https://www.apartments.com/my-account/#SavedSearches" id="menuNavLnkSaveSearches" rel="nofollow">My Saved Searches</a></li>
# <li><a href="https://www.apartments.com/my-account/#FavoriteListings" id="menuNavLnkFavorites" rel="nofollow">My Favorites</a></li>
# <li id="menuNavLnkUserNotificationSettings"><a href="https://www.apartments.com/my-account/#UserNotificationSettings" rel="nofollow"><span>Notification Settings</span></a></li>
# <li>
# <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/">Apartments For Rent<i class="profileCarouselArrowRightIcon"></i><i class="mapZoomInIcon"></i></a>
# <ul class="submenu">
# <li><a href="https://www.apartments.com/san-diego-ca/">San Diego Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/el-cajon-ca/">El Cajon Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/chula-vista-ca/">Chula Vista Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/oceanside-ca/">Oceanside Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/carlsbad-ca/">Carlsbad Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/coronado-ca/">Coronado Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/escondido-ca/">Escondido Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/la-mesa-ca/">La Mesa Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/la-jolla-ca/">La Jolla Apartments For Rent</a></li>
# <li><a href="https://www.apartments.com/vista-ca/">Vista Apartments For Rent</a></li>
# </ul>
# </li>
# <li>
# <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/houses/">Homes For Rent<i class="profileCarouselArrowRightIcon"></i><i class="mapZoomInIcon"></i></a>
# <ul class="submenu">
# <li><a href="https://www.apartments.com/houses/san-diego-ca/">San Diego Homes For Rent</a></li>
# <li><a href="https://www.apartments.com/houses/carlsbad-ca/">Carlsbad Homes For Rent</a></li>
# <li><a href="https://www.apartments.com/houses/la-jolla-ca/">La Jolla Homes For Rent</a></li>
# <li><a href="https://www.apartments.com/houses/oceanside-ca/">Oceanside Homes For Rent</a></li>
# <li><a href="https://www.apartments.com/houses/coronado-ca/">Coronado Homes For Rent</a></li>
# <li><a href="https://www.apartments.com/houses/chula-vista-ca/">Chula Vista Homes For Rent</a></li>
# <li><a href="https://www.apartments.com/houses/del-mar-ca/">Del Mar Homes For Rent</a></li>
# <li><a href="https://www.apartments.com/houses/el-cajon-ca/">El Cajon Homes For Rent</a></li>
# <li><a href="https://www.apartments.com/houses/escondido-ca/">Escondido Homes For Rent</a></li>
# <li><a href="https://www.apartments.com/houses/san-marcos-ca/">San Marcos Homes For Rent</a></li>
# </ul>
# </li>
# <li>
# <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/condos/">Condos For Rent<i class="profileCarouselArrowRightIcon"></i><i class="mapZoomInIcon"></i></a>
# <ul class="submenu">
# <li><a href="https://www.apartments.com/condos/san-diego-ca/">San Diego Condos For Rent</a></li>
# <li><a href="https://www.apartments.com/condos/el-cajon-ca/">El Cajon Condos For Rent</a></li>
# <li><a href="https://www.apartments.com/condos/coronado-ca/">Coronado Condos For Rent</a></li>
# <li><a href="https://www.apartments.com/condos/oceanside-ca/">Oceanside Condos For Rent</a></li>
# <li><a href="https://www.apartments.com/condos/la-mesa-ca/">La Mesa Condos For Rent</a></li>
# <li><a href="https://www.apartments.com/condos/imperial-beach-ca/">Imperial Beach Condos For Rent</a></li>
# <li><a href="https://www.apartments.com/condos/escondido-ca/">Escondido Condos For Rent</a></li>
# <li><a href="https://www.apartments.com/condos/carlsbad-ca/">Carlsbad Condos For Rent</a></li>
# <li><a href="https://www.apartments.com/condos/vista-ca/">Vista Condos For Rent</a></li>
# <li><a href="https://www.apartments.com/condos/chula-vista-ca/">Chula Vista Condos For Rent</a></li>
# </ul>
# </li>
# <li>
# <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/townhomes/">Townhomes For Rent<i class="profileCarouselArrowRightIcon"></i><i class="mapZoomInIcon"></i></a>
# <ul class="submenu">
# <li><a href="https://www.apartments.com/townhomes/san-diego-ca/">San Diego Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/carlsbad-ca/">Carlsbad Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/chula-vista-ca/">Chula Vista Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/carlsbad-carlsbad-ca/">Carlsbad Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/san-diego-ca-92109/">San Diego, CA 92109 Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/san-diego-ca-92108/">San Diego, CA 92108 Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/la-jolla-ca-92037/">La Jolla, CA 92037 Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/carlsbad-ca-92009/">Carlsbad, CA 92009 Townhomes For Rent</a></li>
# <li><a href="https://www.apartments.com/townhomes/san-diego-county-ca/">San Diego County Townhomes For Rent</a></li>
# </ul>
# </li>
# <li><a data-requirelogin="false" href="https://www.apartments.com/mobile/" id="menuNavLnkMobileApps" target="_blank">Mobile Apps</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="headerSwitchLanguageWrapper">
# <a class="headerSwitchLanguage" data-culture="es-US" href="https://www.apartments.com/es/san-diego-ca/28/" title="Español"><i class="worldIcon"></i>Español</a>
# </div>
# <div class="logoSpacer"></div>
# <div class="logo">
# <a href="https://www.apartments.com/">
# <img alt="Apartments.com Logo" src="/a/4d9af0/content/images/apartments-for-rent-logo.png"/>
# </a>
# </div>
# <div class="loginPrevNextWrapper">
# <div class="loginSection" id="headerLoginSection">
# <a class="js-headerSignUp headerSignUp" href="javascript:void(0);" title="Sign Up">Sign Up</a>
# <span>/</span>
# <a class="js-headerSignin headerSignIn" href="javascript:void(0);" title="Sign In">Sign In</a>
# </div>
# </div>
# <a href="javascript:void(0);" id="headerAddListing" title="Add a Listing">
# <span>Add a Listing</span>
# </a>
# </nav>
# </header>
# <script type="application/ld+json">
#     {"@type":"SearchResultsPage","contentLocation":{"containedIn":{"@type":"State","name":"CA"},"@type":"City","name":"San Diego"},"breadcrumb":[{"itemListElement":[{"@type":"ListItem","position":0,"item":{"name":"Home","@id":"https://www.apartments.com/"}},{"@type":"ListItem","position":1,"item":{"name":"California","@id":"https://www.apartments.com/ca/"}},{"@type":"ListItem","position":2,"item":{"name":"San Diego Apartments for Rent","@id":"https://www.apartments.com/san-diego-ca/"}}],"@context":"http://schema.org","@type":"BreadcrumbList"}],"about":[{"url":"https://www.apartments.com/3634-3640-indiana-st-san-diego-ca/fd1c46v/","image":"https://images1.apartments.com/i2/UDVgTCuIjwG9vgSKX5VCv0sXbCuqI4pFUYLWUaNzYuY/104/3634-3640-indiana-st-san-diego-ca-building-photo.jpg","Address":{"@type":"PostalAddress","streetAddress":"3634-3640 Indiana St","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92103","addressCountry":"US"},"telephone":"+1-888-557-4338","@type":"SingleFamilyResidence","name":"3634-3640 Indiana St","@id":"https://www.apartments.com/3634-3640-indiana-st-san-diego-ca/fd1c46v/"},{"url":"https://www.apartments.com/5-br-3-bath-house-12290-brassica-street-san-diego-ca/43t0gwl/","image":"https://images1.apartments.com/i2/9kpWXDEGyKPD1yTcCddzGLJgdeNFHlFDQ_DHx2oNusg/104/5-br-3-bath-house---12290-brassica-street-san-diego-ca-building-photo.jpg","Address":{"@type":"PostalAddress","streetAddress":"12290 Brassica St","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92129","addressCountry":"US"},"telephone":"+1-619-684-5053","@type":"SingleFamilyResidence","name":"5 br, 3 bath House - 12290 Brassica Street","@id":"https://www.apartments.com/5-br-3-bath-house-12290-brassica-street-san-diego-ca/43t0gwl/"},{"url":"https://www.apartments.com/3-br-35-bath-house-15156-lincoln-loop-san-diego-ca/cqmbt6e/","image":"https://images1.apartments.com/i2/Zh9sYHwwFuuMrfFgctM0iisXYHYdkAwi-Eo4wzuOksY/104/3-br-35-bath-house---15156-lincoln-loop-san-diego-ca-building-photo.jpg","Address":{"@type":"PostalAddress","streetAddress":"15156 Lincoln Loop","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92127","addressCountry":"US"},"telephone":"+1-619-708-9393","@type":"SingleFamilyResidence","name":"3 br, 3.5 bath House - 15156 Lincoln Loop","@id":"https://www.apartments.com/3-br-35-bath-house-15156-lincoln-loop-san-diego-ca/cqmbt6e/"},{"url":"https://www.apartments.com/10278-black-mountain-rd-san-diego-ca/ptz9pfs/","image":"https://images1.apartments.com/i2/XW4LqRqQKg-p_5_I0rpZujWMVYjy_sCpu_qD0lSVh8o/104/10278-black-mountain-rd-san-diego-ca-building-photo.jpg","Address":{"@type":"PostalAddress","streetAddress":"10278 Black Mountain Rd","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92126","addressCountry":"US"},"telephone":"+1-858-695-0123","@type":"SingleFamilyResidence","name":"10278 Black Mountain Rd","@id":"https://www.apartments.com/10278-black-mountain-rd-san-diego-ca/ptz9pfs/"},{"url":"https://www.apartments.com/4-br-25-bath-house-3742-via-de-la-bandola-san-diego-ca/kn9d4h9/","image":"https://images1.apartments.com/i2/jCf6ZhRMsdi2atvKVr6dYO-4LFgPe30doV_hBSfHKSA/104/4-br-25-bath-house---3742-via-de-la-bandola-san-diego-ca-building-photo.jpg","Address":{"@type":"PostalAddress","streetAddress":"3742 Via De La Bandola","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92173","addressCountry":"US"},"telephone":"+1-619-804-3325","@type":"SingleFamilyResidence","name":"4 br, 2.5 bath House - 3742 Via De La Bandola","@id":"https://www.apartments.com/4-br-25-bath-house-3742-via-de-la-bandola-san-diego-ca/kn9d4h9/"},{"url":"https://www.apartments.com/4575-arizona-st-san-diego-ca/my73szk/","image":"https://images1.apartments.com/i2/jxxiqmWqcBcHFxfSxmKsz4thwBoWkB5sUeRax2DyV74/104/4575-arizona-st-san-diego-ca-building-photo.jpg","Address":{"@type":"PostalAddress","streetAddress":"4575 Arizona St","addressLocality":"San Diego","addressRegion":"CA","postalCode":"92116","addressC ...
# </script>
# <main>
# <section class="searchApp" id="searchApp">
# <header class="searchBar" id="searchBar">
# <!--[if lte IE 9]>
# <div class="searchBarWrapper no-flex clearfix">
# <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <div class="searchBarWrapper">
# <!--<![endif]-->
# <div class="mainOptionsWrapper">
# <a class="backToSearch primary" data-bind="visible: isBackToSearchVisible(), click: backToSearchClick" href="javascript:void(0);" id="backToSearch" style="display: none;" title="Back to Search">
# <i class="leftArrowIcon"></i>
# <span>Back to Search</span>
# </a>
# <span class="lookup" data-bind="visible: isTypeaheadVisible()">
# <input autocorrect="false" class="searchBarLookup" data-bind="css: { savedSearchVisible: isSavedSearchVisible() }" id="searchBarLookup" placeholder="Location or Point of Interest" type="text"/>
# <a class="location" id="lookupLocation" role="button" title="Locate Me">
# <i class="locationIcon"></i>
# </a>
# </span>
# <span data-bind="with: rentRange, visible: isRentRangeVisible()" id="minMaxRangeControl">
# <div class="rentRangeSelector dropDownContainer" data-bind="css: { active: isOpen() }, event: { keydown: keyDown }">
# <a class="btn btn-default rentselector" data-bind="click: selectorClicked, clickBubble: true" role="button" title="Rent Range" type="button">
# <span data-bind="text: selectedDisplayValue()">Rent Range</span> <span class="caret"></span>
# </a>
# <div class="dropdownContent">
# <div class="ranges">
# <div class="grid firstChild">
# <div class="cell-xs-6">
# <input class="minRentInput" data-bind="css: { active: isMinRentActive() }, event: { focus: minRentFocus, blur: rentInputBlur }, value: minRent, clickBubble: false" maxlength="6" pattern="\$?(\d|\,)*" placeholder="Min Rent" type="tel">
# </input></div>
# <div class="cell-xs-6">
# <input class="maxRentInput" data-bind="css: { active: !isMinRentActive() }, event: { focus: maxRentFocus, blur: rentInputBlur }, value: maxRent, clickBubble: false" maxlength="6" pattern="\$?(\d|\,)*" placeholder="Max Rent" type="tel"/>
# </div>
# </div>
# </div>
# <ul class="minRentOptions js-minRentOptions" data-bind="css: { active: isMinRentActive() }, click: minRentOptionsClicked, clickBubble: false">
# <li class="active" data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="">No Min</li>
# <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="500">$500</li>
# <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="700">$700</li>
# <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="900">$900</li>
# <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="1100">$1,100</li>
# <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="1300">$1,300</li>
# <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="1500">$1,500</li>
# </ul>
# <ul class="maxRentOptions js-maxRentOptions" data-bind="css: { active: !isMinRentActive() }, visible: !minRentHasValue(), click: maxRentOptionsClicked, clickBubble: false" id="maxRentOptions">
# <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1100">$1,100</li>
# <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1300">$1,300</li>
# <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1500">$1,500</li>
# <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1700">$1,700</li>
# <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1900">$1,900</li>
# <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="2100">$2,100</li>
# <li class="active" data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="">No Max</li>
# </ul>
# <ul class="maxRentOptions js-customMaxRentOptions" data-bind="foreach: maxRentValues, css: { active: !isMinRentActive() }, visible: minRentHasValue(), click: maxRentOptionsClicked, clickBubble: false">
# <li data-bind="text: text, attr: { 'data-value': value },  css: { active: $parent.isMaxRangeOptionActive($element) }, scrollIntoView: $parent.isMaxRangeOptionActive($element) &amp;&amp; !$parent.isMinRentActive()"></li>
# </ul>
# </div>
# </div>
# </span>
# <span data-bind="with: bedBaths, visible: isBedBathsVisible()" id="bedBathControl">
# <!-- ko if: isActive() -->
# <div class="dropdownBackdrop" data-bind="click: deactivate, clickBubble: false"></div>
# <!-- /ko -->
# <div class="bedBathSelector dropDownContainer" data-bind="css: { active: isActive }">
# <a class="btn btn-default" data-bind="click: toggleActive, clickBubble: true" role="button" title="Bedrooms &amp; Bathrooms">
# <span data-bind="text: selectedDisplay">Beds x Baths</span> <span class="caret"></span>
# </a>
# <div class="dropdownContent">
# <h4>BEDS</h4>
# <ul>
# <li data-bind="clickSetValue: beds, clickBubble: false" data-value="">
# <input class="primaryRadio" data-bind="reverseInputBinding: bedOptions, checked: beds, preventBubble: 'click', enable: isEnabled(6 ,')'" data-text="All Beds" name="bedGroup" type="radio" value=""/>
# <label><span>All Beds</span></label>
# </li>
# <li data-bind="clickSetValue: beds, clickBubble: false" data-value="-1">
# <input class="primaryRadio" data-bind="reverseInputBinding: bedOptions, checked: beds, preventBubble: 'click', enable: isEnabled(6 ,'-1)'" data-text="Studio" name="bedGroup" type="radio" value="-1"/>
# <label><span>Studio</span></label>
# </li>
# <li data-bind="clickSetValue: beds, clickBubble: false" data-value="1">
# <input class="primaryRadio" data-bind="reverseInputBinding: bedOptions, checked: beds, preventBubble: 'click', enable: isEnabled(6 ,'1)'" data-text="1 Bed" name="bedGroup" type="radio" value="1"/>
# <label><span>1 Bed</span></label>
# </li>
# <li data-bind="clickSetValue: beds, clickBubble: false" data-value="2">
# <input class="primaryRadio" data-bind="reverseInputBinding: bedOptions, checked: beds, preventBubble: 'click', enable: isEnabled(6 ,'2)'" data-text="2 Beds" name="bedGroup" type="radio" value="2"/>
# <label><span>2 Beds</span></label>
# </li>
# <li data-bind="clickSetValue: beds, clickBubble: false" data-value="3">
# <input class="primaryRadio" data-bind="reverseInputBinding: bedOptions, checked: beds, preventBubble: 'click', enable: isEnabled(6 ,'3)'" data-text="3 Beds" name="bedGroup" type="radio" value="3"/>
# <label><span>3 Beds</span></label>
# </li>
# <li data-bind="clickSetValue: beds, clickBubble: false" data-value="4">
# <input class="primaryRadio" data-bind="reverseInputBinding: bedOptions, checked: beds, preventBubble: 'click', enable: isEnabled(6 ,'4)'" data-text="4+ Beds" name="bedGroup" type="radio" value="4"/>
# <label><span>4+ Beds</span></label>
# </li>
# </ul>
# <h4>BATHS</h4>
# <ul>
# <li data-bind="clickSetValue: baths, clickBubble: false" data-value="">
# <input class="primaryRadio" data-bind="reverseInputBinding: bathOptions, checked: baths, preventBubble: 'click', enable: isEnabled(7 ,')'" data-text="All Baths" name="bathGroup" type="radio" value=""/>
# <label><span>All Baths</span></label>
# </li>
# <li data-bind="clickSetValue: baths, clickBubble: false" data-value="1">
# <input class="primaryRadio" data-bind="reverseInputBinding: bathOptions, checked: baths, preventBubble: 'click', enable: isEnabled(7 ,'1)'" data-text="1+ Baths" name="bathGroup" type="radio" value="1"/>
# <label><span>1+ Baths</span></label>
# </li>
# <li data-bind="clickSetValue: baths, clickBubble: false" data-value="2">
# <input class="primaryRadio" data-bind="reverseInputBinding: bathOptions, checked: baths, preventBubble: 'click', enable: isEnabled(7 ,'2)'" data-text="2+ Baths" name="bathGroup" type="radio" value="2"/>
# <label><span>2+ Baths</span></label>
# </li>
# <li data-bind="clickSetValue: baths, clickBubble: false" data-value="3">
# <input class="primaryRadio" data-bind="reverseInputBinding: bathOptions, checked: baths, preventBubble: 'click', enable: isEnabled(7 ,'3)'" data-text="3+ Baths" name="bathGroup" type="radio" value="3"/>
# <label><span>3+ Baths</span></label>
# </li>
# </ul>
# </div>
# </div>
# </span>
# <span id="advancedFilterCombo">
# <a class="filterToggle" data-bind="visible: isAdvancedFiltersVisible(), css: { active: isAdvancedFiltersActive(), rentBedBathActive: hasRentOrBedBathFiltersApplied()}, click: toggleAdvancedFilters" id="advancedFiltersIcon" role="button" title="Search apartments by amenities or commute time">
# <span class="filtersText">Filter</span>
# </a>
# </span>
# </div>
# <div class="optionsWrapper">
# <div class="secondaryOptions " data-bind="css: { savedSearchVisible: isSavedSearchVisible()}">
# <div class="clearSavedSearchContainer">
# <button class="clear hidden secondary" data-bind="visible: isClearVisible(), click: triggerClear, css: { hidden: false}" title="See all apartments available now in this area" type="button">Clear</button>
# <button class="primary" data-bind="visible: isSaveSearchVisible(), click: triggerSavedSearch" id="saveSearchIcon" title="Save this apartment search" type="button">
# <span class="short">Save Search</span>
# </button>
# </div>
# <a class="localGuideBtn " data-bind="css: { noContent: !isLocalGuideButtonVisible(), campusGuideBtn: shouldDisplayCampusGuide(), localGuideBtn: !shouldDisplayCampusGuide()},
#                        attr: { title: neighborhoodTitle}, text: localGuideLabel(), visible: isNeighborhoodVisible(), click: openLocalGuide" data-initial-visibility="true" id="nhUrl" role="button" title="Learn more about living in San Diego">
#                         Local Guide
#                     </a>
# <a class="newBtn" data-bind="click: newSearchClickHandler, visible: isNewVisible(), css: { active: isNewSearchMode()}, attr: {href : newModeSearchUrl()}" role="button">
# <span class="newTitle">New</span>
# <span class="newNum" data-bind="text: newListingsCountDisplay(), visible: !isNewSearchMode(), css: { active: newListingsCount() &gt; 0 }"></span>
# <i class="circleCloseIcon" data-bind="visible: isNewSearchMode()" style="display:none"></i>
# </a>
# <a class="saveSearchBtn" data-bind="click: savedSearchesClickHandler, css: { active: isSavedSearchMode() }" role="button">
# <i class="alertBell2Icon"></i>
# <span class="saveSearchNum" data-bind="text: savedSearchText(), visible: !isSavedSearchMode(), css: { active: savedSearchCount() &gt; 0 }"></span>
# <i class="circleCloseIcon" data-bind="visible: isSavedSearchMode()" style="display:none"></i>
# </a>
# <a class="favoritesBtn" data-bind="css: {active: isFavoriteMode()}, click: toggleViewFavorites" id="favoritesIcon" role="button" title="Favorites">
# <span class="heartOutlineIcon"></span>
# <span class="heartFilledIcon"></span>
# <span class="favoritesNum" data-bind="text: favoritesCountText(), css: {'active': favoritesCount() &gt; 0}"></span>
# <i class="circleCloseIcon" data-bind="visible: favoritesCount() &amp;&amp; isFavoriteMode()" style="display:none"></i>
# </a>
# <div class="dropDownContainer sortBy" data-bind="css: { active: isSortMenuActive()}">
# <a class="sortBtn" data-bind="click: toggleSortMenu, css: {'active': isSortMenuVisible}" role="button">
# <i class="sortByArrowsIcon"></i>
# <span class="sortBtnTitle">Sort</span>
# </a>
# <div class="dropdownContent" data-bind="visible: isSortMenuVisible(), css: {'active': isSortMenuVisible}">
# <ul class="sortMenu" data-bind="foreach: sortOptions" id="sortMenu">
# <li class="sort" data-bind="attr: {title: Item2}, click: $parent.sortMenuOptionClick, css: {active: $parent.sortMode() == Item1}">
# <span class="sortOptionText" data-bind="text: Item3"></span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <section class="advancedFiltersContainer" id="advancedFiltersContainer">
# <div class="tabWrapper">
# <ul class="tabHeader">
# <li class="active" data-tab-id="advancedFiltersTab">
# <a class="advancedFiltersTabText" href="javascript:void(0);" title="Search Filters">Search Filters</a>
# </li>
# <li data-tab-id="myPlacesTab">
# <a class="myPlacesTabText" href="javascript:void(0);" title="Plan My Commute">Plan My Commute</a>
# </li>
# </ul>
# </div>
# <div class="tabContent active advancedFilters" data-tab-content-id="advancedFiltersTab" id="advancedFilters">
# <div class="content">
# <section class="advancedFilterSection lowestRes">
# <div class="rentRange">
# <h2>Rent Range</h2>
# <div class="grid firstChild">
# <div class="cell-xs-6 minWrapper">
# <input class="minRentInput" maxlength="6" pattern="$?(\d|\,)*" placeholder="Enter Min Rent" type="tel"/>
# </div>
# <div class="cell-xs-6 maxWrapper">
# <input class="maxRentInput" maxlength="6" pattern="$?(\d|\,)*" placeholder="Enter Max Rent" type="tel"/>
# </div>
# </div>
# </div>
# <div class="bedsBaths">
# <div class="beds clearfix">
# <h2>Beds</h2>
# <ul id="advancedFilterBeds">
# <li data-path="6" data-value="">
# <a href="https://www.apartments.com/san-diego-ca/" title=""> <input class="primaryRadio" data-path="Listing.MinBeds" data-value="" id="_beds" type="radio"/>
# <label for="_beds">
# <span>All Beds </span>
# </label>
# </a> </li>
# <li data-path="6" data-value="-1">
# <a href="https://www.apartments.com/san-diego-ca/studios/" title=""> <input class="primaryRadio" data-path="Listing.MinBeds" data-value="-1" id="-1_beds" type="radio"/>
# <label for="-1_beds">
# <span>Studio </span>
# </label>
# </a> </li>
# <li data-path="6" data-value="1">
# <a href="https://www.apartments.com/san-diego-ca/1-bedrooms/" title=""> <input class="primaryRadio" data-path="Listing.MinBeds" data-value="1" id="1_beds" type="radio"/>
# <label for="1_beds">
# <span>1 Bed </span>
# </label>
# </a> </li>
# <li data-path="6" data-value="2">
# <a href="https://www.apartments.com/san-diego-ca/2-bedrooms/" title=""> <input class="primaryRadio" data-path="Listing.MinBeds" data-value="2" id="2_beds" type="radio"/>
# <label for="2_beds">
# <span>2 Beds </span>
# </label>
# </a> </li>
# <li data-path="6" data-value="3">
# <a href="https://www.apartments.com/san-diego-ca/3-bedrooms/" title=""> <input class="primaryRadio" data-path="Listing.MinBeds" data-value="3" id="3_beds" type="radio"/>
# <label for="3_beds">
# <span>3 Beds </span>
# </label>
# </a> </li>
# <li data-path="6" data-value="4">
# <a href="https://www.apartments.com/san-diego-ca/4-bedrooms/" title=""> <input class="primaryRadio" data-path="Listing.MinBeds" data-value="4" id="4_beds" type="radio"/>
# <label for="4_beds">
# <span>4+ Beds </span>
# </label>
# </a> </li>
# </ul>
# </div>
# <div class="baths clearfix">
# <h2>Baths</h2>
# <ul id="advancedFilterBaths">
# <li data-path="7" data-value="">
# <input class="primaryRadio" data-path="Listing.MinBaths" data-value="" id="_baths" type="radio"/>
# <label for="_baths">
# <span>All Baths</span>
# </label>
# </li>
# <li data-path="7" data-value="1">
# <input class="primaryRadio" data-path="Listing.MinBaths" data-value="1" id="1_baths" type="radio"/>
# <label for="1_baths">
# <span>1+ Baths</span>
# </label>
# </li>
# <li data-path="7" data-value="2">
# <input class="primaryRadio" data-path="Listing.MinBaths" data-value="2" id="2_baths" type="radio"/>
# <label for="2_baths">
# <span>2+ Baths</span>
# </label>
# </li>
# <li data-path="7" data-value="3">
# <input class="primaryRadio" data-path="Listing.MinBaths" data-value="3" id="3_baths" type="radio"/>
# <label for="3_baths">
# <span>3+ Baths</span>
# </label>
# </li>
# </ul>
# </div>
# </div>
# </section>
# <section class="advancedFilterSection clearfix">
# <div class="desktopView clearfix">
# <h2 class="amenitiesHeading">Interior &amp; Community Amenities</h2>
# <ul id="advancedFilterUnitAmenities">
# <li data-path="3" data-value="16">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="16" id="UnitAmenities_16" type="checkbox"/>
# <label for="UnitAmenities_16"><span>Air Conditioning</span><span class="facetCount">(3569)</span></label>
# </a> </li>
# <li data-path="3" data-value="2">
# <a href="https://www.apartments.com/san-diego-ca/washer-dryer/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="2" id="UnitAmenities_2" type="checkbox"/>
# <label for="UnitAmenities_2"><span>In Unit Washer &amp; Dryer</span><span class="facetCount">(2956)</span></label>
# </a> </li>
# <li data-path="3" data-value="1048576">
# <a href="https://www.apartments.com/san-diego-ca/washer_dryer-hookup/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="1048576" id="UnitAmenities_1048576" type="checkbox"/>
# <label for="UnitAmenities_1048576"><span>Washer &amp; Dryer Hookups</span><span class="facetCount">(486)</span></label>
# </a> </li>
# <li data-path="3" data-value="4">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="4" id="UnitAmenities_4" type="checkbox"/>
# <label for="UnitAmenities_4"><span>Dishwasher</span><span class="facetCount">(3859)</span></label>
# </a> </li>
# <li data-path="3" data-value="131072">
# <a href="https://www.apartments.com/san-diego-ca/wheelchair-accessible/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="131072" id="UnitAmenities_131072" type="checkbox"/>
# <label for="UnitAmenities_131072"><span>Wheelchair Access</span><span class="facetCount">(1675)</span></label>
# </a> </li>
# <li data-path="3" data-value="65536">
# <a href="https://www.apartments.com/san-diego-ca/parking/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="65536" id="CommunityAmenities_65536" type="checkbox"/>
# <label for="CommunityAmenities_65536"><span>Parking</span><span class="facetCount">(5224)</span></label>
# </a> </li>
# <li data-path="3" data-value="2097152">
# <a href="https://www.apartments.com/san-diego-ca/laundry-facilities/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="2097152" id="CommunityAmenities_2097152" type="checkbox"/>
# <label for="CommunityAmenities_2097152"><span>Laundry Facilities</span><span class="facetCount">(2278)</span></label>
# </a> </li>
# <li data-path="3" data-value="256">
# <a href="https://www.apartments.com/san-diego-ca/fitness-center/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="256" id="CommunityAmenities_256" type="checkbox"/>
# <label for="CommunityAmenities_256"><span>Fitness Center</span><span class="facetCount">(4362)</span></label>
# </a> </li>
# <li data-path="3" data-value="512">
# <a href="https://www.apartments.com/san-diego-ca/pool/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="512" id="CommunityAmenities_512" type="checkbox"/>
# <label for="CommunityAmenities_512"><span>Pool</span><span class="facetCount">(4632)</span></label>
# </a> </li>
# <li data-path="3" data-value="524288">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="524288" id="CommunityAmenities_524288" type="checkbox"/>
# <label for="CommunityAmenities_524288"><span>Elevator</span><span class="facetCount">(2058)</span></label>
# </a> </li>
# <li data-path="2" data-value="1">
# <a href="https://www.apartments.com/san-diego-ca/pet-friendly-dog/" title=""> <input class="primaryCheckbox" data-path="Listing.PetFriendly" data-value="1" id="PetFriendly_1" type="checkbox"/>
# <label for="PetFriendly_1"><span>Dog Friendly</span><span class="facetCount">(4723)</span></label>
# </a> </li>
# <li data-path="2" data-value="2">
# <a href="https://www.apartments.com/san-diego-ca/pet-friendly-cat/" title=""> <input class="primaryCheckbox" data-path="Listing.PetFriendly" data-value="2" id="PetFriendly_2" type="checkbox"/>
# <label for="PetFriendly_2"><span>Cat Friendly</span><span class="facetCount">(4903)</span></label>
# </a> </li>
# <li data-path="3" data-value="128">
# <a href="https://www.apartments.com/san-diego-ca/furnished/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="128" id="AdditionalAmenities_128" type="checkbox"/>
# <label for="AdditionalAmenities_128"><span>Furnished</span><span class="facetCount">(705)</span></label>
# </a> </li>
# <li data-path="3" data-value="8388608">
# <a href="https://www.apartments.com/san-diego-ca/lofts/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="8388608" id="AdditionalAmenities_8388608" type="checkbox"/>
# <label for="AdditionalAmenities_8388608"><span>Lofts</span><span class="facetCount">(351)</span></label>
# </a> </li>
# <li data-path="3" data-value="4194304">
# <a href="https://www.apartments.com/san-diego-ca/utilities-included/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="4194304" id="AdditionalAmenities_4194304" type="checkbox"/>
# <label for="AdditionalAmenities_4194304"><span>Utilities Included</span><span class="facetCount">(1396)</span></label>
# </a> </li>
# </ul>
# </div>
# <div class="tabletView clearfix">
# <h2>Interior &amp; Community Amenities</h2>
# <ul id="advancedFilterUnitAmenities">
# <li data-path="3" data-value="16">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="16" id="UnitAmenities_16" type="checkbox"/>
# <label for="UnitAmenities_16"><span>Air Conditioning</span><span class="facetCount">(3569)</span></label>
# </a> </li>
# <li data-path="3" data-value="2">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="2" id="UnitAmenities_2" type="checkbox"/>
# <label for="UnitAmenities_2"><span>In Unit W/D</span><span class="facetCount">(2956)</span></label>
# </a> </li>
# <li data-path="3" data-value="1048576">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="1048576" id="UnitAmenities_1048576" type="checkbox"/>
# <label for="UnitAmenities_1048576"><span>W/D Hookups</span><span class="facetCount">(486)</span></label>
# </a> </li>
# <li data-path="3" data-value="4">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="4" id="UnitAmenities_4" type="checkbox"/>
# <label for="UnitAmenities_4"><span>Dishwasher</span><span class="facetCount">(3859)</span></label>
# </a> </li>
# <li data-path="3" data-value="131072">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="131072" id="UnitAmenities_131072" type="checkbox"/>
# <label for="UnitAmenities_131072"><span>Wheelchair Access</span><span class="facetCount">(1675)</span></label>
# </a> </li>
# <li data-path="3" data-value="65536">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="65536" id="CommunityAmenities_65536" type="checkbox"/>
# <label for="CommunityAmenities_65536"><span>Parking</span><span class="facetCount">(5224)</span></label>
# </a> </li>
# <li data-path="3" data-value="2097152">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="2097152" id="CommunityAmenities_2097152" type="checkbox"/>
# <label for="CommunityAmenities_2097152"><span>Laundry Facilities</span><span class="facetCount">(2278)</span></label>
# </a> </li>
# <li data-path="3" data-value="256">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="256" id="CommunityAmenities_256" type="checkbox"/>
# <label for="CommunityAmenities_256"><span>Fitness Center</span><span class="facetCount">(4362)</span></label>
# </a> </li>
# <li data-path="3" data-value="512">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="512" id="CommunityAmenities_512" type="checkbox"/>
# <label for="CommunityAmenities_512"><span>Pool</span><span class="facetCount">(4632)</span></label>
# </a> </li>
# <li data-path="3" data-value="524288">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="524288" id="CommunityAmenities_524288" type="checkbox"/>
# <label for="CommunityAmenities_524288"><span>Elevator</span><span class="facetCount">(2058)</span></label>
# </a> </li>
# <li data-path="2" data-value="1">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.PetFriendly" data-value="1" id="PetFriendly_1" type="checkbox"/>
# <label for="PetFriendly_1"><span>Dog Friendly</span><span class="facetCount">(4723)</span></label>
# </a> </li>
# <li data-path="2" data-value="2">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.PetFriendly" data-value="2" id="PetFriendly_2" type="checkbox"/>
# <label for="PetFriendly_2"><span>Cat Friendly</span><span class="facetCount">(4903)</span></label>
# </a> </li>
# <li data-path="3" data-value="128">
# <a href="https://www.apartments.com/san-diego-ca/furnished/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="128" id="AdditionalAmenities_128" type="checkbox"/>
# <label for="AdditionalAmenities_128"><span>Furnished</span><span class="facetCount">(705)</span></label>
# </a> </li>
# <li data-path="3" data-value="8388608">
# <a href="https://www.apartments.com/san-diego-ca/lofts/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="8388608" id="AdditionalAmenities_8388608" type="checkbox"/>
# <label for="AdditionalAmenities_8388608"><span>Lofts</span><span class="facetCount">(351)</span></label>
# </a> </li>
# <li data-path="3" data-value="4194304">
# <a href="https://www.apartments.com/san-diego-ca/utilities-included/" title=""> <input class="primaryCheckbox" data-path="Listing.Amenities" data-value="4194304" id="AdditionalAmenities_4194304" type="checkbox"/>
# <label for="AdditionalAmenities_4194304"><span>Utilities Included</span><span class="facetCount">(1396)</span></label>
# </a> </li>
# </ul>
# </div>
# <div class="style clearfix">
# <h2>Style</h2>
# <ul id="advancedFilterStyle">
# <li data-path="5" data-value="1">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Style" data-value="1" id="StyleSmall_1" type="checkbox"/>
# <label for="StyleSmall_1"><span>Apartments</span><span class="facetCount">(5543)</span></label>
# </a> </li>
# <li data-path="5" data-value="2">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Style" data-value="2" id="StyleSmall_2" type="checkbox"/>
# <label for="StyleSmall_2"><span>Houses</span><span class="facetCount">(495)</span></label>
# </a> </li>
# <li data-path="5" data-value="4">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Style" data-value="4" id="StyleSmall_4" type="checkbox"/>
# <label for="StyleSmall_4"><span>Condos</span><span class="facetCount">(406)</span></label>
# </a> </li>
# <li data-path="5" data-value="16">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Style" data-value="16" id="StyleSmall_16" type="checkbox"/>
# <label for="StyleSmall_16"><span>Townhomes</span><span class="facetCount">(72)</span></label>
# </a> </li>
# </ul>
# </div>
# <div class="rating clearfix">
# <h2>Rating</h2>
# <ul id="advancedFilterRating">
# <li data-path="4" data-value="16">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Ratings" data-value="16" id="Rating_16" type="checkbox"/>
# <label for="Rating_16">
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <span class="facetCount">(4539)</span>
# </label>
# </a> </li>
# <li data-path="4" data-value="8">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Ratings" data-value="8" id="Rating_8" type="checkbox"/>
# <label for="Rating_8">
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <span class="facetCount">(707)</span>
# </label>
# </a> </li>
# <li data-path="4" data-value="4">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Ratings" data-value="4" id="Rating_4" type="checkbox"/>
# <label for="Rating_4">
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <span class="facetCount">(81)</span>
# </label>
# </a> </li>
# <li data-path="4" data-value="2">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Ratings" data-value="2" id="Rating_2" type="checkbox"/>
# <label for="Rating_2">
# <i class="starFullIcon"></i>
# <i class="starFullIcon"></i>
# <span class="facetCount">(3)</span>
# </label>
# </a> </li>
# </ul>
# </div>
# <div class="desktopView specialties clearfix">
# <h2>Specialties</h2>
# <ul id="advancedFilterSpecialties">
# <li data-path="1" data-value="1">
# <a href="https://www.apartments.com/san-diego-ca/senior-housing/" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="1" id="Specialties_1" type="checkbox"/>
# <label for="Specialties_1"><span>Senior Housing</span><span class="facetCount">(78)</span></label>
# </a> </li>
# <li data-path="1" data-value="2">
# <a href="https://www.apartments.com/san-diego-ca/?spc=military" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="2" id="Specialties_2" type="checkbox"/>
# <label for="Specialties_2"><span>Military Housing</span><span class="facetCount">(113)</span></label>
# </a> </li>
# <li data-path="1" data-value="4">
# <a href="https://www.apartments.com/san-diego-ca/student-housing/" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="4" id="Specialties_4" type="checkbox"/>
# <label for="Specialties_4"><span>Student Housing</span><span class="facetCount">(73)</span></label>
# </a> </li>
# <li data-path="1" data-value="8">
# <a href="https://www.apartments.com/san-diego-ca/?spc=corporate" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="8" id="Specialties_8" type="checkbox"/>
# <label for="Specialties_8"><span>Corporate Housing</span><span class="facetCount">(74)</span></label>
# </a> </li>
# <li data-path="1" data-value="32">
# <a href="https://www.apartments.com/san-diego-ca/low-income/" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="32" id="Specialties_32" type="checkbox"/>
# <label for="Specialties_32"><span>Affordable</span><span class="facetCount">(186)</span></label>
# </a> </li>
# <li data-path="1" data-value="64">
# <a href="https://www.apartments.com/san-diego-ca/luxury/" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="64" id="Specialties_64" type="checkbox"/>
# <label for="Specialties_64"><span>Luxury</span><span class="facetCount">(1015)</span></label>
# </a> </li>
# <li data-path="1" data-value="128">
# <a href="https://www.apartments.com/san-diego-ca/cheap/" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="128" id="Specialties_128" type="checkbox"/>
# <label for="Specialties_128"><span>Cheap</span><span class="facetCount">(977)</span></label>
# </a> </li>
# <li data-path="1" data-value="16">
# <a href="https://www.apartments.com/san-diego-ca/short-term/" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="16" id="AdditionalSpecialties_16" type="checkbox"/>
# <label for="AdditionalSpecialties_16"><span>Short Term</span><span class="facetCount">(1142)</span></label>
# </a> </li>
# </ul>
# </div>
# <div class="tabletView specialties clearfix">
# <h2>Specialties</h2>
# <ul id="advancedFilterSpecialties">
# <li data-path="1" data-value="1">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="1" id="Specialties_1" type="checkbox"/>
# <label for="Specialties_1"><span>Senior</span><span class="facetCount">(78)</span></label>
# </a> </li>
# <li data-path="1" data-value="8">
# <a href="javascript:void(0);" title=""> <input class="primaryCheckbox" data-path="Listing.Specialties" data-value="8" id="Specialties_8" type="checkbox"/>
# <label for="Specialties_8"><span>Corporate</span><span class="facetCount">(74)</span></label>
# </a> </li>
# <li data-path="1" data-value="2">
# ...
# <div class="totalSavedSearches" data-bind="visible: isTotalSavedSearchesVisible()" style="display: none;">
# <span data-bind="text: totalRecordsDisplay()"></span>
# </div>
# <div data-bind="foreach: summaries">
# <article class="summaryWrapper" data-bind="click: runSearchClickHandler, css: { hasNewListings: hasNewListings() }">
# <div class="savedSearchInfoContainer">
# <div class="newAvailableListings">
# <span class="newListings" data-bind="text: newListingsText()"></span>
# <span class="unreadAlertsEnd" data-bind="visible: !isNew">Matching Saved Search Criteria</span>
# </div>
# <div class="name" data-bind="text: name"></div>
# <div class="summary" data-bind="text: summary"></div>
# </div>
# <div class="runSearchBtnContainer" data-bind="visible: !isPreview">
# <button class="runSearch"><i class="homepageCarouselArrowRightIcon"></i></button>
# </div>
# </article>
# </div>
# <div class="loading" data-bind="css: { active: isLoading() || isLoadingMore() }">
# <div class="spinner"></div>
# </div>
# <div class="saveWrapper" data-bind="visible: isPreview()" style="display: none;">
# <button class="primary saveBtn" data-bind="click: save" title="Save this apartment search" type="button">
# <span>Save</span>
# </button>
# </div>
# </div>
# </div>
# </section>
# </div>
# <div class="contactLead" data-backdrop="static" id="contactLead">
# <div class="contactLeadWrapper" id="contactLeadForm">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3>
# <i class="phoneIcon"></i>
# <span class="contactPhone"></span>
# </h3>
# <div class="contactForm">
# <div class="cell-xs-6 first-input">
# <input class="contactFormFirstName" placeholder="First Name *" type="text"/>
# </div>
# <div class="cell-xs-6 last-input">
# <input class="contactFormLastName" placeholder="Last Name *" type="text"/>
# </div>
# <div class="cell-xs-6 first-input">
# <input class="contactFormEmail" placeholder="Email Address *" type="email"/>
# </div>
# <div class="cell-xs-6 last-input">
# <input class="contactFormPhoneNumber" id="phone" placeholder="Phone" type="tel"/>
# </div>
# <div class="cell-xs-12" id="ContactViaContainer">
# <select class="selectpicker" id="ContactVia" type="text">
# <option id="defaultContactSelect" value="-1">Contact Via</option>
# <option value="1">Phone</option>
# <option value="2">Email</option>
# </select>
# </div>
# <div class="cell-xs-12" id="MaxRentContainer">
# <input class="contactFormMaxRent" id="MaxRent" inputmode="numeric" maxlength="6" pattern="[0-9\/]*" placeholder="Max Rent" type="text"/>
# </div>
# <div class="cell-xs-12" id="BedsBathsContainer">
# <div class="cell-xs-6 first-input" id="bedContainer">
# <select class="selectpicker" id="Beds" type="text">
# <option id="defaultBedSelect" value="-1">Beds</option>
# <option value="0">Studio</option>
# <option value="1">1 Bed</option>
# <option value="2">2 Beds</option>
# <option value="3">3 Beds</option>
# <option value="4">4+ Beds</option>
# </select>
# </div>
# <div class="cell-xs-6 last-input" id="bathContainer">
# <select class="selectpicker" id="Baths" type="text">
# <option id="defaultBathSelect" value="-1">Baths</option>
# <option value="1">1+ Baths</option>
# <option value="2">2+ Baths</option>
# <option value="3">3+ Baths</option>
# </select>
# </div>
# </div>
# <div class="cell-xs-12">
# <div class="calendar-input">
# <i class="calendarIcon"></i>
# <input class="contactFormMoveInDate" placeholder="Move-In Date *" type="text">
# </input></div>
# </div>
# <div class="cell-xs-12" id="ReasonForMovingContainer">
# <select class="selectpicker" id="ReasonForMoving" type="text">
# <option id="defaulReasonSelect" value="-1">Reason for Moving</option>
# <option value="1">More/Less Space</option>
# <option value="2">Job Change</option>
# <option value="3">Family Event</option>
# <option value="4">Relocation</option>
# <option value="5">Other</option>
# </select>
# </div>
# <div class="cell-xs-12 contactFormMessageWrapper">
# <textarea class="contactFormMessage" placeholder="Message"></textarea>
# </div>
# <input checked="" class="optin primaryCheckbox emailListings" id="emailListings" type="checkbox">
# <label class="emailListingsLabel" for="emailListings"><span>Email me listings and apartment related info.</span></label>
# <div class="cell-xs-12 submitError">
# <input id="submitGeneralError" type="hidden">
# </input></div>
# <a class="primary contactFormAction" href="javascript:void(0);"><i class="emailIcon"></i>Contact Property</a>
# </input></div>
# </div>
# <div id="submitSpinnerModalWrapper">
# <div class="submitRequestSpinner fade modalContainer" data-backdrop="static" id="submitRequestSpinner">
# <div class="spinner"></div>
# <p>Submitting Request</p>
# </div>
# </div>
# <div id="successModalWrapper">
# <div class="fade out successModal modalContainer" data-backdrop="static" id="successModal">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3>Thank You</h3>
# <p class="message">Thank you! Your email has been sent.</p>
# </div>
# </div>
# </div>
# <div class="searchFavoritesModals" id="searchFavoritesModals">
# <div class="modal fade noFavoritesYetModal" data-backdrop="static" id="noFavoritesYetModal">
# <div class="modalContainer">
# <div class="modalContent">
# <button class="closeIcon" data-dismiss="modal" id="close" type="button"></button>
# <h3>No Favorites Yet</h3>
# <p>You haven't favorited a listing yet. Once you favorite a listing you can filter the map to show only your favorites. Click a heart to get started!</p>
# <button class="primary" data-dismiss="modal" id="confirm" type="button">Ok</button>
# </div>
# </div>
# </div>
# <div class="modal fade clearFiltersModal" data-backdrop="static" id="clearFiltersModal">
# <div class="modalContainer">
# <div class="modalContent">
# <button class="closeIcon" data-dismiss="modal" id="close" type="button"></button>
# <h3>Clear Filters</h3>
# <p>Please note that by filtering favorites, all of your filters including drawn searches and my Plan Commute searches will be cleared.</p>
# <p>Would you like to continue?</p>
# <button class="primary" id="confirm" type="button">Yes</button>
# <button class="secondary" data-dismiss="modal" id="reject" type="button">No</button>
# </div>
# </div>
# </div>
# </div>
# <div class="myPlacesErrorModal modal fade" data-backdrop="static" id="myPlacesErrorModal">
# <div class="modalContainer">
# <div class="modalContent">
# <button class="closeIcon" id="errorClose" type="button"></button>
# <h3>We're Sorry</h3>
# <p>We had some problems performing your search.  Please try again.</p>
# <button class="primary first" id="errorModalTryAgain" type="button">Try again</button>
# <button class="primary" id="errorModalExit" type="button">Exit</button>
# </div>
# </div>
# </div>
# <div class="modal fade searchErrorModal" data-backdrop="static" id="searchErrorModal">
# <div class="modalContainer">
# <div class="modalContent">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3>We're Sorry!</h3>
# <p>We had some problems performing your search.  Please try again later.</p>
# <button class="primary" data-dismiss="modal" type="button">Ok</button>
# </div>
# </div>
# </div>
# <div class="modal fade locateMeErrorModal" data-backdrop="static" id="locateMeErrorModal">
# <div class="modalContainer">
# <div class="modalContent">
# <button class="closeIcon" data-dismiss="modal" type="button"></button>
# <h3>We're Sorry!</h3>
# <p>Your location was not found. Please try again later.</p>
# <button class="primary" data-dismiss="modal" type="button">Ok</button>
# </div>
# </div>
# </div>
# <div id="geoNoContentNotification"></div>
# <div class="videoPlayerWrapper fade modal" id="modalVirtualTourContainer">
# <div class="videoPlayerWrapper" id="virtualTourVideoPlayerWrapper">
# <div class="viewerContent" id="virtualTourViewerContent">
# <div class="videoPlayer active" id="virtualTourVideoPlayer">
# <div class="poweredMatterport"></div>
# <button class="close closeIcon" data-dismiss="modal" type="button"></button>
# <div class="videoPlayerContent" id="virtualTourPlayerContent"></div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </main>
# </div>
# <div class="modals"></div>
# <script type="text/javascript">
#         var LogManagerConfig = {
#             Source: 'Apartments',
#             PostUrl: '/services/log/',
#             MachineKey: 'IJ5ADbZMTzl+fjKAjcGC/wkKoGW4ohJ/Vigak4iz6Ac='
#         };
#         window._moduleLoadTimeout = 30;
#     </script>
# <script src="/scripts/scripts.en-us.bundle.js?v=He9PSP-Uv_xupbPlueiRv0bfafsKpfG7XW-TlNcOb9U"></script>
# <script>
#     require(['configuration'], function(configuration) {
#         configuration.configure({
#             debugLevel: 0,
#             mode: 'desktop',
#             operatingSystemType: 'macos',
#
#             culture: 'en-US',
#             alternateCultureLinks: [{"u":"https://www.apartments.com/es/san-diego-ca/28/","n":"Español","c":"es-US"}],
#
# 			securedAppDomain: 'https://www.apartments.com',
# 			appDomain: 'https://www.apartments.com',
# 			activityLoggingApiRoot: 'https://www.apartments.com/',
# 		    enableBoundedSearch: true,
#
# 			cookieDomain: '.apartments.com',
# 			myPlacesEntries: 7,
# 			FacebookAppId: '739299276152207',
# 			GoogleClientId: '584308931288-s77uuon9vudl4n0vumhu14sggrit46b4.apps.googleusercontent.com',
# 			GoogleApiKey: 'AIzaSyC8m7Iic_Ua4j0_JxFtwJMyz-Iqjtv08Ws',
# 			GoogleReCaptchaSiteKey: '6LfTDSgTAAAAAMgNPKDdkNqxq81KTDWrL7gOabTt',
# 			ensightenBootstrapUrl: '//nexus.ensighten.com/apartments/Bootstrap.js',
# 			comscoreClientId: '18075227',
# 			googleAnalyticsKey: 'UA-1746553-2',
#             googleTagManagerKey: 'GTM-5CC6LZ6',
#             enableGoogleTagManager: false,
#             googleOptimizeKey: 'GTM-TS2M8NB',
#             enableGoogleOptimize: true,
#             googleDoubleClickFloodlightKey: 'DC-6337982',
# 			maxFavorites: 10,
# 			eventMaxParallel: 4,
# 			placardDefferredImage: true,
# 			showListingFreshnessOption: true,
# 			ajaxTimeout: 60000,
# 			virtualTourUrl: 'https://my.matterport.com/show/?model=',
# 			maxSearchHistory: 6,
# 			maxProfileViewHistory: 20,
# 			authCookieExpires: 1,
#             ratingsAndReviewsToUUrl: 'https://www.apartments.com/advertise/disclaimers/ratings-and-reviews-terms-of-use/',
#             apartmentsToSUrl: 'https://www.apartments.com/advertise/disclaimers/terms-of-service/',
# 			enableSmsAddEdit: false,
# 			maxFileUploadSize: 75,
# 			unitCountThreshold: 2,
# 			googleMapsPath: 'https://maps.googleapis.com/maps/api/js?client=gme-costargroupinc2&channel=apartments&v=3.34',
# 			enableSavedSearchesLoginPopupFeature: false,
# 			showEspanol: true,
#             enableExploreNeighborhoods: false,
#
# 			adTaggingEnabled: true,
# 			activityLoggingEnabled: true,
# 			enableGeoIPFallbackCall: true,
# 			enableInfoCardsV2: true,
#             enableVectorGeoShape: true,
#             enableVectorRemoveOutline: false,
#             mtExpireDays: 30,
#             enableOl: false,
#             isContactedRentalEnabled: false,
#             enableCaptcha: true,
#             enableFreeRentSign: true,
#             freeRentSignRequestTimeLimit: 30,
#             enableIdVisionLoginFeature: false,
#             enableCA: true
# 		});
#     });
# </script>
# <script src="/Modules/Search/Scripts/search.bundle.js?v=9YaJeVuF5nqtea0fjAQk5Z4k_jETFQNtPliRhGv35uw"></script>
# <script type="text/javascript">
#         require(['SearchStartup'],
#             function(startup) {
#
#             startup.init({
#                 resultState: {"ResultKey":null,"MetaState":{"Title":null,"PagePreviousUrl":null,"PageNextUrl":null,"FirstImageUrl":null,"Follow":null,"LocationMeta":{"PinImage":null,"GeographyType":2}},"UrlState":{"Url":"https://www.apartments.com/san-diego-ca/28/","CanonicalUrl":"https://www.apartments.com/san-diego-ca/28/","NewModeSearchUrl":"https://www.apartments.com/san-diego-ca/new/28/","NeighborhoodUrl":"https://www.apartments.com/san-diego-ca/#guide","cus":[{"u":"https://www.apartments.com/es/san-diego-ca/28/","n":"Español","c":"es-US"}]},"PinsState":{"cl":"y4vrvtr|1|null|33.04942|-117.0718|0~erl9gvm|1|null|33.03388|-117.11371|0~517s4bp|5|null|33.03303|-117.08956|0~xrnt15p|1|null|33.03138|-117.08971|0~pnkh3yr|1|null|33.03068|-117.06369|0~kddxd5c|1|null|33.02746|-117.07702|0~60vc1vt|1|null|33.02645|-117.08083|0~bn7z709|1|null|33.02609|-117.10461|0~cqmbt6e|1|null|33.02365|-117.11246|0~64c2wps|1|null|33.02251|-117.11373|0~t46myeb|1|null|33.02218|-117.06008|0~74xrplx|3|null|33.02132|-117.11559|0~51v0wsq|3|null|33.01284|-117.07358|0~j05xxh5|3|null|33.00505|-117.09618|0~jvvg7n5|1|null|33.00412|-117.0609|0~bhrmbjb|1|null|33.00251|-117.05968|0~9vf65l6|1|null|33.00002|-117.06587|0~3sdb1zf|1|null|32.9993|-117.06282|0~fjzzryv|4|null|32.99822|-117.06829|0~32hpyvg|1|null|32.9981|-117.09753|0~l3rfxfg|5|null|32.99784|-117.08522|0~zgc9fyz|1|null|32.99777|-117.25468|0~4fc3w6k|5|null|32.99716|-117.25885|0~9xyydz5|1|null|32.9964|-117.09116|0~kmcel58|3|null|32.99266|-117.21307|0~g5twm2z|1|null|32.98986|-117.16418|0~gpejz6y|1|null|32.98979|-117.16506|0~j93nqw4|1|null|32.98937|-117.0675|0~llzmp1g|4|null|32.98836|-117.09034|0~3tecfdg|1|null|32.98693|-117.1641|0~zl48kmx|3|null|32.98532|-117.26216|0~c55mnxf|3|null|32.98315|-117.26006|0~053vdd3|1|null|32.98157|-117.26041|0~pb9qh1v|1|null|32.98121|-117.26571|0~fd1rx8s|3|null|32.97899|-117.07725|0~mrwkymk|3|null|32.97621|-117.08267|0~xjfdlnm|1|null|32.97591|-117.07247|0~kmwpnpc|5|null|32.97576|-117.09258|0~793mcqw|3|null|32.97465|-117.08388|0~xsr4s4q|1|null|32.97418|-117.13118|0~m0nx6bj|3|null|32.97196|-117.26784|0~yp1y1pr|1|null|32.97121|-117.07977|0~d5dq2fh|1|null|32.97043|-117.15702|0~dyw3c2k|1|null|32.96953|-117.2383|0~9k1rmx6|1|null|32.96951|-117.17347|0~69dssjs|1|null|32.96724|-117.08738|0~4zyqp5h|1|null|32.96225|-117.18347|0~6mesd5t|2|null|32.962|-117.09133|0~vptzldf|1|null|32.96163|-117.16055|0~n0xnw2m|5|null|32.96109|-117.18862|0~s18elk4|4|null|32.96102|-117.06272|0~rddcwp0|2|null|32.95927|-117.06407|0~mtbfv9j|1|null|32.95883|-117.11669|0~68jbrcv|3|null|32.9578|-117.23375|0~r4ynl41|1|null|32.95683|-117.14833|0~3w2mz2f|3|null|32.95633|-117.23392|0~sdjnx85|5|null|32.95441|-117.22834|0~prh84jv|1|null|32.95431|-117.2427|0~wbzymkh|3|null|32.95348|-117.10898|0~d6w7cdl|3|null|32.9526|-117.24654|0~sfxz1c5|1|null|32.95237|-117.22942|0~wsrgy9k|1|[{\"ListingId\":\"wsrgy9k\",\"Favorite\":0,\"IsTierTwo\":false},{\"ListingId\":\"wcvh36l\",\"Favorite\":0,\"IsTierTwo\":false}]|32.95207|-117.24737|0~f8ql5rt|3|null|32.95196|-117.05788|0~p2mxg4s|5|null|32.95131|-117.10974|0~e3z6kkq|1|null|32.95091|-117.13699|0~xznyrhq|1|null|32.95019|-117.1093|0~jq2erb7|1|null|32.9501|-117.14783|0~g3n0l0y|2|null|32.95001|-117.06084|0~4gbvgqh|3|null|32.94839|-117.10806|0~q0cdw8x|1|null|32.94803|-117.22865|0~99mv1p5|3|null|32.94774|-117.26148|0~sgg5z45|4|null|32.94724|-117.23589|0~730xx2x|1|null|32.946|-117.26236|0~8jregx3|1|null|32.94506|-117.23784|0~cpzw1qg|1|null|32.94459|-117.23565|0~ky05xgb|2|null|32.94448|-117.08885|0~e8jec6p|1|null|32.94414|-117.23106|0~ge6y56w|4|null|32.94384|-117.08819|0~43t0gwl|1|null|32.94292|-117.14373|0~v1xkk0f|3|null|32.94113|-117.11279|0~j94ezm7|4|null|32.93899|-117.11272|0~0dw9qg3|1|null|32.93543|-117.25418|0~blhhcyb|3|null|32.93423|-117.22442|0~q8mx2sw|1|null|32.93308|-117.08471|0~g6e06vz|3|null|32.92962|-117.12386|0~06syjz3|1|null|32.92743|-117.1406|0~ymfje5t|1|null|32.92711|-117.15793|0~gddl7hz|3|null|32.9271|-117.14219|0~wew2wxh|1|null|32.92683|-117.15596|0~zhgzlbx|1|null|32.92383|-117.16 ...
#                 sortOptions: [{"Item1":0,"Item2":"Sort","Item3":"Default"},{"Item1":2,"Item2":"Rent","Item3":"Rent (low to high)"},{"Item1":1,"Item2":"Rent","Item3":"Rent (high to low)"},{"Item1":4,"Item2":"Video","Item3":"Video"},{"Item1":6,"Item2":"3D Tour","Item3":"3D Tour"},{"Item1":8,"Item2":"Last Updated","Item3":"Last Updated"}],
#                 redirectState: null
#             });
#         });
#     </script>
# <link href="/Modules/Profile/Content/style.bundle.css?v=R_kGqkytp8-UlsyyGehT8nneYhHAkDJccRAz0iXMyEY" rel="prefetch"/><link href="/Modules/Profile/Scripts/profile.shared.bundle.js?v=O0VbP2fRLNh9RyLu5eANPFCsSEk_QL7NRXp32M1g1pM" rel="prefetch"/>
# <noscript><img src="https://www.apartments.com/akam/10/pixel_82f471b?a=dD01N2IyNmM3Y2QwYjQyOTM3YmRkNTAzNDM1NTBiMjkxZWFjNjAzNjQ5JmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/></noscript></body>
# </html>

# %% [markdown]
# ## The Beautiful Soup parses the content and we can see it produces what looks like real HTML
# ### PHEW

# %%
# To extract the first and last page numbers
# Since we want more than just one page of listings
## we will set the first and last pages to variables and loop through
paging = soup.find("div",{"id":"placardContainer"}).find("div",{"id":"paging"}).find_all("a")
start_page = paging[1].text
last_page = paging[len(paging)-2].text
web_content_list = [] # we are instantiating this so that we can loop and add content after looping

# %% [markdown]
# Now the looping:
#
# for each page ranging from the start ot last page, we will:
# - request content
# - parse with bs4
# - find content of interest
# - put content in instantiated web_content_list

# %%
for page_number in range(int(start_page),int(last_page) + 1):
    
    # To form the url based on page numbers
    url = base_url+str(page_number)+"/.html"
    r = requests.get(base_url+str(page_number)+"/", headers=headers)
    c = r.content
    soup = BeautifulSoup(c,"html.parser")
    
    # To extract the Title and the Location
    placard_header = soup.find_all("header",{"class":"placardHeader"})
    
    # To extract the Rent, No of Beds and Phone Number
    placard_content = soup.find_all("section",{"class" :"placardContent"})
    
    # To process property by property by looping
    for item_header,item_content in zip(placard_header,placard_content):
         # To store the information to a dictionary
          web_content_dict = {}
          web_content_dict["Title"]=item_header.find("a",{"class":"placardTitle"}).text.replace("\r","").replace("\n","")
          web_content_dict["Address"] = item_header.find("div",{"class":"location"}).text
          web_content_dict["Price"] = item_content.find("span",{"class":"altRentDisplay"}).text
          web_content_dict["Beds"] = item_content.find("span",{"class":"unitLabel"}).text
          web_content_dict["Phone"] = item_content.find("div",{"class":"phone"}).find("span").text
          # To store the dictionary to into a list
          web_content_list.append(web_content_dict)

# %% [markdown]
# ## Lastly, now that we have our content:
# ### We will put it into a pandas dataframe
# ### and convert to csv file

# %%
# To make a dataframe with the list
df = pandas.DataFrame(web_content_list)

# convert to CSV
df.to_csv("EXAMPLE.csv")
